# %% [markdown]
# # SMILES enumeration, vectorization and batch generation
#
# [![Smiles Enumeration Header](https://www.wildcardconsulting.dk/wp-content/uploads/2017/03/Smiles_Enumeration_girl_600px.png)](https://www.wildcardconsulting.dk/useful-information/smiles-enumeration-as-data-augmentation-for-molecular-neural-networks/)

# %% [markdown]
# SMILES enumeration is the process of writing out all possible SMILES forms of a molecule. It's a useful technique for data augmentation before sequence based modeling of molecules. You can read more about the background in this [blog post](https://www.wildcardconsulting.dk/useful-information/smiles-enumeration-as-data-augmentation-for-molecular-neural-networks/) or [this preprint on arxiv.org](https://arxiv.org/abs/1703.07076)

# %% [markdown]
# Import the SmilesEnumerator and instantiate the object

# %%
from SmilesEnumerator import SmilesEnumerator
sme = SmilesEnumerator()
# print help(SmilesEnumerator)
# Out:
# RDKit WARNING: [17:10:55] Enabling RDKit 2019.09.2 jupyter extensions

# %% [markdown]
# A few SMILES strings will be enumerated as a demonstration.

# %%
for i in range(100):
    print (sme.randomize_smiles("CCC(=O)O[C@@]1(CC[NH+](C[C@H]1CC=C)C)c2ccccc2"))
# Out:
# O=C(O[C@]1(c2ccccc2)CC[NH+](C)C[C@H]1CC=C)CC
# C[NH+]1C[C@@H](CC=C)[C@](c2ccccc2)(OC(CC)=O)CC1
# [C@@H]1(CC=C)C[NH+](C)CC[C@@]1(c1ccccc1)OC(CC)=O
# CCC(=O)O[C@@]1(c2ccccc2)[C@H](CC=C)C[NH+](C)CC1
# [C@H]1(CC=C)[C@](c2ccccc2)(OC(=O)CC)CC[NH+](C)C1
# O([C@@]1(c2ccccc2)[C@H](CC=C)C[NH+](C)CC1)C(CC)=O
# C(=O)(O[C@]1(c2ccccc2)CC[NH+](C)C[C@H]1CC=C)CC
# C=CC[C@@H]1C[NH+](C)CC[C@]1(OC(=O)CC)c1ccccc1
# c1c([C@@]2(OC(CC)=O)CC[NH+](C)C[C@H]2CC=C)cccc1
# [C@H]1(CC=C)[C@@](OC(CC)=O)(c2ccccc2)CC[NH+](C)C1
# c1cc([C@]2(OC(CC)=O)[C@H](CC=C)C[NH+](C)CC2)ccc1
# C1[C@@](c2ccccc2)(OC(=O)CC)[C@H](CC=C)C[NH+](C)C1
# [NH+]1(C)CC[C@@](c2ccccc2)(OC(CC)=O)[C@H](CC=C)C1
# [NH+]1(C)C[C@@H](CC=C)[C@@](OC(CC)=O)(c2ccccc2)CC1
# [C@@]1(c2ccccc2)(OC(CC)=O)[C@H](CC=C)C[NH+](C)CC1
# C([C@@H]1C[NH+](C)CC[C@]1(OC(=O)CC)c1ccccc1)C=C
# c1cc([C@]2(OC(=O)CC)[C@H](CC=C)C[NH+](C)CC2)ccc1
# [C@H]1(CC=C)[C@](c2ccccc2)(OC(CC)=O)CC[NH+](C)C1
# c1([C@]2(OC(=O)CC)[C@H](CC=C)C[NH+](C)CC2)ccccc1
# ...

# %%
for i in range(1000):
    print(sme.randomize_smiles('[OH:1][c:2]1[cH:3][cH:4][cH:5][c:6]2[c:7]1[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@H:17]([C:18]([NH:19][CH3:20])=[O:21])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:27][CH:28]([CH3:29])[CH3:30])(=[O:31])[OH:32])[C:33]2=[O:34]'))
# Out:
# [CH:28]([CH2:27][CH:14]([C:15]([NH:16][C@H:17]([C:18](=[O:21])[NH:19][CH3:20])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:13][P:12]([OH:32])([CH2:11][N:10]1[C:33](=[O:34])[c:6]2[cH:5][cH:4][cH:3][c:2]([OH:1])[c:7]2[C:8]1=[O:9])=[O:31])([CH3:29])[CH3:30]
# [c:6]12[c:7]([c:2]([OH:1])[cH:3][cH:4][cH:5]1)[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@@H:17]([CH2:22][CH:23]([CH3:24])[CH3:25])[C:18](=[O:21])[NH:19][CH3:20])=[O:26])[CH2:27][CH:28]([CH3:30])[CH3:29])(=[O:31])[OH:32])[C:33]2=[O:34]
# [cH:3]1[c:2]([OH:1])[c:7]2[c:6]([cH:5][cH:4]1)[C:33](=[O:34])[N:10]([CH2:11][P:12]([OH:32])(=[O:31])[CH2:13][CH:14]([C:15](=[O:26])[NH:16][C@@H:17]([CH2:22][CH:23]([CH3:24])[CH3:25])[C:18](=[O:21])[NH:19][CH3:20])[CH2:27][CH:28]([CH3:30])[CH3:29])[C:8]2=[O:9]
# ...

# %%
smiles = [sme.randomize_smiles('[OH:1][c:2]1[cH:3][cH:4][cH:5][c:6]2[c:7]1[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@H:17]([C:18]([NH:19][CH3:20])=[O:21])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:27][CH:28]([CH3:29])[CH3:30])(=[O:31])[OH:32])[C:33]2=[O:34]')for i in range(10000)]

# %%
len(smiles)
# Out:
# 10000

# %%
from rdkit import Chem

# %%
test_smiles = sme.randomize_smiles('[OH:1][c:2]1[cH:3][cH:4][cH:5][c:6]2[c:7]1[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@H:17]([C:18]([NH:19][CH3:20])=[O:21])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:27][CH:28]([CH3:29])[CH3:30])(=[O:31])[OH:32])[C:33]2=[O:34]')
test_mol = Chem.MolFromSmiles(test_smiles)
print(test_smiles)
test_mol
# Out:
# [OH:1][c:2]1[cH:3][cH:4][cH:5][c:6]2[c:7]1[C:8](=[O:9])[N:10]([CH2:11][P:12](=[O:31])([OH:32])[CH2:13][CH:14]([CH2:27][CH:28]([CH3:29])[CH3:30])[C:15](=[O:26])[NH:16][C@@H:17]([CH2:22][CH:23]([CH3:25])[CH3:24])[C:18](=[O:21])[NH:19][CH3:20])[C:33]2=[O:34]

# %%
for a in test_mol.GetAtoms():
    print(a.GetSmarts())
# Out:
# [OH:1]
# [c:2]
# [cH:3]
# [cH:4]
# [cH:5]
# [c:6]
# [c:7]
# [C:8]
# [O:9]
# [N:10]
# [CH2:11]
# [P:12]
# [O:31]
# [OH:32]
# [CH2:13]
# [CH:14]
# [CH2:27]
# [CH:28]
# [CH3:29]
# [CH3:30]
# [C:15]
# [O:26]
# [NH:16]
# [C@@H:17]
# [CH2:22]
# [CH:23]
# [CH3:25]
# [CH3:24]
# [C:18]
# [O:21]
# [NH:19]
# [CH3:20]
# [C:33]
# [O:34]

# %%
# 自己测试代码块

# %%
def bond_to_label_ignore_map(bond):
    '''This function takes an RDKit bond and creates a label describing
    the most important attributes'''
    # atoms = sorted([atom_to_label(bond.GetBeginAtom().GetIdx()), \
    #               atom_to_label(bond.GetEndAtom().GetIdx())])
    a1_label = str(bond.GetBeginAtom().GetAtomicNum())
    a2_label = str(bond.GetEndAtom().GetAtomicNum())
    # if bond.GetBeginAtom().HasProp('molAtomMapNumber'):
    #     a1_label += bond.GetBeginAtom().GetProp('molAtomMapNumber')
    # if bond.GetEndAtom().HasProp('molAtomMapNumber'):
    #     a2_label += bond.GetEndAtom().GetProp('molAtomMapNumber')
    atoms = sorted([a1_label, a2_label])

    return '{}{}{}'.format(atoms[0], bond.GetSmarts(), atoms[1])

def atoms_are_different_c2maped(atom1, atom2):
    '''Compares two RDKit atoms based on basic properties'''

    if atom1.GetAtomicNum() != atom2.GetAtomicNum(): return True
    if atom1.GetAtomicNum() != atom2.GetAtomicNum(): return True # must be true for atom mapping
    if atom1.GetTotalNumHs() != atom2.GetTotalNumHs(): return True
    if atom1.GetFormalCharge() != atom2.GetFormalCharge(): return True
    if atom1.GetDegree() != atom2.GetDegree(): return True
    #if atom1.IsInRing() != atom2.IsInRing(): return True
    if atom1.GetNumRadicalElectrons() != atom2.GetNumRadicalElectrons(): return True
    if atom1.GetIsAromatic() != atom2.GetIsAromatic(): return True
    # TODO: add # pi electrons like ICSynth?

    # Check bonds and nearest neighbor identity
    bonds1 = sorted([bond_to_label_ignore_map(bond) for bond in atom1.GetBonds()])
    bonds2 = sorted([bond_to_label_ignore_map(bond) for bond in atom2.GetBonds()])
    if bonds1 != bonds2: return True

        # # Check neighbors too (already taken care of with previous lines)
        # neighbors1 = sorted([atom.GetAtomicNum() for atom in atom1.GetNeighbors()])
        # neighbors2 = sorted([atom.GetAtomicNum() for atom in atom2.GetNeighbors()])
        # if neighbors1 != neighbors2: return True

    # print('bonds1: {}'.format(bonds1))
    # print('bonds2: {}'.format(bonds2))

    return False

def atom_nei_are_different(atom1,atom2):
    if atoms_are_different_c2maped(atom1,atom2):return True
    for nei1 in atom1.GetNeighbors():
        true_list = [atoms_are_different_c2maped(nei1,nei2) for nei2 in atom2.GetNeighbors()]
    if False not in true_list:
        return True
    else:return False

# %%
canonical_smiles = 'CNC(=O)[C@H](CC(C)C)NC(=O)C(CC(C)C)CP(=O)(O)CN1C(=O)c2cccc(O)c2C1=O'
canonical_mol = Chem.MolFromSmiles(canonical_smiles)
flag = True
while flag:
    maped_random_smiles = sme.randomize_smiles('[OH:1][c:2]1[cH:3][cH:4][cH:5][c:6]2[c:7]1[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@H:17]([C:18]([NH:19][CH3:20])=[O:21])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:27][CH:28]([CH3:29])[CH3:30])(=[O:31])[OH:32])[C:33]2=[O:34]')
    maped_mol = Chem.MolFromSmiles(maped_random_smiles)
    true_list = []
    can_atoms = [a for a in canonical_mol.GetAtoms()]
    maped_atoms = [a for a in maped_mol.GetAtoms()]
    for i,atom1 in enumerate(can_atoms):
        if atom_nei_are_different(atom1, maped_atoms[i]):
            true_list.append(1)
    if len(true_list) == 0:
        flag = False
print(maped_random_smiles)
# Out:
# [CH3:20][NH:19][C:18](=[O:21])[C@H:17]([CH2:22][CH:23]([CH3:25])[CH3:24])[NH:16][C:15](=[O:26])[CH:14]([CH2:27][CH:28]([CH3:30])[CH3:29])[CH2:13][P:12](=[O:31])([OH:32])[CH2:11][N:10]1[C:33](=[O:34])[c:6]2[cH:5][cH:4][cH:3][c:2]([OH:1])[c:7]2[C:8]1=[O:9]

# %%
maped_random_mol = Chem.MolFromSmiles('[CH3:20][NH:19][C:18](=[O:21])[C@H:17]([CH2:22][CH:23]([CH3:24])[CH3:25])[NH:16][C:15](=[O:26])[CH:14]([CH2:27][CH:28]([CH3:29])[CH3:30])[CH2:13][P:12](=[O:31])([OH:32])[CH2:11][N:10]1[C:33](=[O:34])[c:6]2[cH:5][cH:4][cH:3][c:2]([OH:1])[c:7]2[C:8]1=[O:9]')
map_used = [a.GetProp('molAtomMapNumber') for a in maped_random_mol.GetAtoms()]
map_used
# Out:
# ['20',
#  '19',
#  '18',
#  '21',
#  '17',
#  '22',
#  '23',
#  '24',
#  '25',
#  '16',
#  '15',
#  '26',
#  '14',
#  '27',
#  '28',
#  '29',
#  '30',
#  '13',
#  '12',
#  '31',
#  '32',
#  '11',
#  '10',
#  '33',
#  '34',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '7',
#  '8',
#  '9']

# %%
canonical_smiles = 'C#CC(C)(C)OC(C)Oc1ccc(NC(=O)N(C)C)cc1Cl'
canonical_mol = Chem.MolFromSmiles(canonical_smiles)
flag = True
while flag:
    maped_random_smiles = sme.randomize_smiles('[CH:1]([O:2][C:3]([C:4]#[CH:5])([CH3:6])[CH3:7])([CH3:8])[O:19][c:18]1[cH:17][cH:16][c:15]([NH:14][C:12]([N:10]([CH3:9])[CH3:11])=[O:13])[cH:22][c:20]1[Cl:21]')
    maped_mol = Chem.MolFromSmiles(maped_random_smiles)
    true_list = []
    can_atoms = [a for a in canonical_mol.GetAtoms()]
    maped_atoms = [a for a in maped_mol.GetAtoms()]
    for i,atom1 in enumerate(can_atoms):
        if atom_nei_are_different(atom1, maped_atoms[i]):
            true_list.append(1)
    if len(true_list) == 0:
        flag = False
print(maped_random_smiles)
# Out:
# [CH:5]#[C:4][C:3]([CH3:7])([CH3:6])[O:2][CH:1]([CH3:8])[O:19][c:18]1[cH:17][cH:16][c:15]([NH:14][C:12](=[O:13])[N:10]([CH3:11])[CH3:9])[cH:22][c:20]1[Cl:21]

# %%
map_used
# Out:
# ['20',
#  '19',
#  '18',
#  '21',
#  '17',
#  '22',
#  '23',
#  '24',
#  '25',
#  '16',
#  '15',
#  '26',
#  '14',
#  '27',
#  '28',
#  '29',
#  '30',
#  '13',
#  '12',
#  '31',
#  '32',
#  '11',
#  '10',
#  '33',
#  '34',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '7',
#  '8',
#  '9']

# %%
def if_have_map(atom):
    if atom.HasProp('molAtomMapNumber'):
        return atom.GetProp('molAtomMapNumber')
    else:return ''

# %%
map_used = map_used
flag = True
while flag:
    maped_random_smiles = sme.randomize_smiles('c1ccc(C[O:1][c:2]2[cH:3][cH:4][cH:5][c:6]3[c:7]2[C:8](=[O:9])[N:10]([CH2:11][P:12]([CH2:13][CH:14]([C:15]([NH:16][C@H:17]([C:18]([NH:19][CH3:20])=[O:21])[CH2:22][CH:23]([CH3:24])[CH3:25])=[O:26])[CH2:27][CH:28]([CH3:29])[CH3:30])(=[O:31])[OH:32])[C:33]3=[O:34])cc1')
    maped_mol = Chem.MolFromSmiles(maped_random_smiles)
    true_list = []

    maped_atom_map = [if_have_map(a) for a in maped_mol.GetAtoms()]
    maped_atom_map_ = []
    for s in maped_atom_map:
        if s is not '':
            maped_atom_map_.append(s)
    for i,map1 in enumerate(map_used):
        if map1 != maped_atom_map_[i]:
            true_list.append(1)
    if len(true_list) <= 4:
        flag = False
print(maped_random_smiles)
# Out:
# [CH3:20][NH:19][C:18](=[O:21])[C@H:17]([CH2:22][CH:23]([CH3:24])[CH3:25])[NH:16][C:15](=[O:26])[CH:14]([CH2:27][CH:28]([CH3:29])[CH3:30])[CH2:13][P:12](=[O:31])([OH:32])[CH2:11][N:10]1[C:33](=[O:34])[c:6]2[cH:5][cH:4][cH:3][c:2]([O:1]Cc3ccccc3)[c:7]2[C:8]1=[O:9]

# %%
maped_atom_map = [if_have_map(a) for a in maped_mol.GetAtoms()]
maped_atom_map_
# Out:
# ['17',
#  '16',
#  '15',
#  '14',
#  '27',
#  '28',
#  '30',
#  '29',
#  '13',
#  '12',
#  '31',
#  '32',
#  '11',
#  '10',
#  '8',
#  '9',
#  '7',
#  '2',
#  '1',
#  '3',
#  '4',
#  '5',
#  '6',
#  '33',
#  '34',
#  '26',
#  '22',
#  '23',
#  '24',
#  '25',
#  '18',
#  '21',
#  '19',
#  '20']

# %%
sme.randomize_smiles('CC1(C)OB([c:1]2[cH:2][cH:3][c:4]([C@@H:5]([CH2:6][C:7]([O:8][CH3:9])=[O:10])[NH:11][C:12](=[O:13])[O:14][C:15]([CH3:16])([CH3:17])[CH3:18])[cH:19][cH:20]2)OC1(C)C.I[c:21]1[c:22]2[c:23]([NH2:24])[n:25][cH:26][n:27][c:28]2[n:29]([S:30](=[O:31])(=[O:32])[c:33]2[cH:34][cH:35][cH:36][cH:37][cH:38]2)[cH:39]1')
# Out:
# '[O:8]([C:7]([CH2:6][C@@H:5]([NH:11][C:12]([O:14][C:15]([CH3:16])([CH3:18])[CH3:17])=[O:13])[c:4]1[cH:3][cH:2][c:1](B2OC(C)(C)C(C)(C)O2)[cH:20][cH:19]1)=[O:10])[CH3:9].[c:33]1([S:30](=[O:32])([n:29]2[cH:39][c:21](I)[c:22]3[c:28]2[n:27][cH:26][n:25][c:23]3[NH2:24])=[O:31])[cH:38][cH:37][cH:36][cH:35][cH:34]1'

# %%
#自己测试代码块
# Out:
# 9160

# %% [markdown]
# ## Vectorization

# %% [markdown]
# Before vectorization SMILES must be stored as strings in an numpy array. The transform takes numpy arrays or pandas series with the SMILES as strings.

# %%
import numpy as np
smiles = np.array(["CCC(=O)O[C@@]1(CC[NH+](C[C@H]1CC=C)C)c2ccccc2"])
print smiles.shape
# Out:
# (1,)

# %% [markdown]
# Fit the charset and the padding to the SMILES array, alternatively they can be specified when instantiating the object.

# %%
sme.fit(smiles)
print sme.charset
print sme.pad
# Out:
# @C)(+=cON12H[]
# 50

# %% [markdown]
# There have been added some extra padding to the maximum lenght observed in the smiles array. The SMILES can be transformed to one-hot encoded vectors and showed with matplotlib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
vect = sme.transform(smiles)
plt.imshow(vect[0])

# %% [markdown]
# It's a nice piano roll. If the vectorization is repeated, the vectorization will be different due to the enumeration, as sme.enum and sme.canonical is set to True and False, respectively (default settings).

# %%
print sme.enumerate, sme.canonical
vect = sme.transform(smiles)
plt.imshow(vect[0])
# Out:
# True False

# %% [markdown]
# The reverse_transform() function can be used to translate back to a SMILES string, as long as the charset is the same as was used to vectorize.

# %%
print sme.reverse_transform(vect)
# Out:
# ['C(C[C@@H]1C[NH+](C)CC[C@@]1(c1ccccc1)OC(CC)=O)=C']

# %% [markdown]
# ## Batch generation for Keras RNN modeling

# %% [markdown]
# The SmilesEnumerator class can be used together with the SmilesIterator batch generator for on the fly vectorization for RNN modeling of molecules. Below it's briefly demonstrated how this can be done.

# %%
import pandas as pd

data = pd.read_csv("Example_data/Sutherland_DHFR.csv")
print data.head()
# Out:
#    Unnamed: 0                                      smiles_parent PC_uM_sign  \
# 0           0                      CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1        NaN
# 1           1                  CCc1nc(N)nc(N)c1-c1ccc(Cl)c(Cl)c1        NaN
# 2           2                   Cc1nc(N)nc(N)c1-c1ccc(Cl)c(Cl)c1        NaN
# 3           3                CCOCc1nc(N)nc(N)c1-c1ccc(Cl)c(Cl)c1        NaN
# 4           4  Nc1nc(N)c(-c2ccc(Cl)cc2)c(COc2ccc([N+](=O)[O-]...        NaN
#
#    PC_uM_value
# 0         3.70
# 1         1.08
# 2         1.68
# 3        12.70
# 4        85.10

# %%
from sklearn.cross_validation import train_test_split

#We ignore the > signs, and use random splitting for simplicity
X_train,  X_test, y_train, y_test = train_test_split(data["smiles_parent"],
                                                     np.log(data["PC_uM_value"]).values.reshape(-1,1),
                                                     random_state=42)

from sklearn.preprocessing import RobustScaler
rbs = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(5.0, 95.0), copy=True)
y_train = rbs.fit_transform((y_train))
y_test = rbs.transform(y_test)
_ = plt.hist(y_train, bins=25)

# %%
import keras.backend as K
from SmilesEnumerator import SmilesIterator
#The SmilesEnumerator must be fit to the entire dataset, so that all chars are registered
sme.fit(data["smiles_parent"])
sme.leftpad = True
print sme.charset
print sme.pad
#The dtype is set for the K.floatx(), which is the numerical type configured for Tensorflow or Theano
generator = SmilesIterator(X_train, y_train, sme, batch_size=200, dtype=K.floatx())
# Out:
# Using TensorFlow backend.
# CBFIHcONS[r]#)(+-lon1s3254=
# 75

# %%
X,y = generator.next()
print X.shape
print y.shape
# Out:
# (200, 75, 27)
# (200, 1)

# %% [markdown]
# Build a SMILES based RNN QSAR model with Keras.

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers.core import Dropout
from keras.callbacks import ReduceLROnPlateau
from keras import regularizers
from keras.optimizers import RMSprop, Adam

# %%
input_shape = X.shape[1:]
output_shape = 1

model = Sequential()
model.add(LSTM(64,
               input_shape=input_shape,
               dropout = 0.19
               #unroll= True
              ))
model.add(Dense(output_shape,
                kernel_regularizer=regularizers.l1_l2(0.005,0.01),
                activation="linear"))

model.compile(loss="mse", optimizer=RMSprop(lr=0.005))
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_23 (LSTM)               (None, 64)                23552
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 65
# ...
# Total params: 23,617
# Trainable params: 23,617
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Use the generator object for training.

# %%
model.fit_generator(generator, steps_per_epoch=100, epochs=25, workers=4)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 20s 203ms/step - loss: 0.15431s - loss
# Epoch 2/25
# 100/100 [==============================] - 16s 156ms/step - loss: 0.1090
# Epoch 3/25
# 100/100 [==============================] - 16s 156ms/step - loss: 0.09302s - loss: - ETA: 1s - l
# Epoch 4/25
# 100/100 [==============================] - 16s 159ms/step - loss: 0.0830
# Epoch 5/25
# 100/100 [==============================] - 16s 157ms/step - loss: 0.0773
# Epoch 6/25
# 100/100 [==============================] - 15s 155ms/step - loss: 0.07310s - loss: 0.07
# Epoch 7/25
# 100/100 [==============================] - 16s 155ms/step - loss: 0.0698
# Epoch 8/25
# 100/100 [==============================] - 16s 156ms/step - loss: 0.0679
# Epoch 9/25
# 100/100 [==============================] - 15s 155ms/step - loss: 0.0676
# Epoch 10/25
# 100/100 [==============================] - 15s 155ms/step - loss: 0.0635
# Epoch 11/25
# ...

# %%
y_pred_train = model.predict(sme.transform(X_train))
y_pred_test = model.predict(sme.transform(X_test))
plt.scatter(y_train, y_pred_train, label="Train")
plt.scatter(y_test, y_pred_test, label="Test")
plt.legend()

# %% [markdown]
# Not the best model until now. However, prolonged training with lowering of the learning rate towards the end will improve the model.

# %%
#The Enumerator can be used in sampling
i = 1

y_true = y_test[i]
y_pred = model.predict(sme.transform(X_test.iloc[i:i+1]))
print y_true - y_pred
# Out:
# [[-0.38300244]]

# %%
#Enumeration of the SMILES before sampling stabilises the result
smiles_repeat = np.array([X_test.iloc[i:i+1].values[0]]*50)
y_pred = model.predict(sme.transform(smiles_repeat))
print y_pred.std()
print y_true - np.median(y_pred)
_ = plt.hist(y_pred)
# Out:
# 0.0616476
# [-0.10707214]

# %% [markdown]
# ## Bibliography
#
# Please cite: [SMILES enumeration as Data Augmentation for Network Modeling of Molecules](https://arxiv.org/abs/1703.07076)
#
# ```bibtex
# @article{DBLP:journals/corr/Bjerrum17,
#   author    = {Esben Jannik Bjerrum},
#   title     = {{SMILES} Enumeration as Data Augmentation for Neural Network Modeling
#                of Molecules},
#   journal   = {CoRR},
#   volume    = {abs/1703.07076},
#   year      = {2017},
#   url       = {http://arxiv.org/abs/1703.07076},
#   timestamp = {Wed, 07 Jun 2017 14:40:38 +0200},
#   biburl    = {http://dblp.uni-trier.de/rec/bib/journals/corr/Bjerrum17},
#   bibsource = {dblp computer science bibliography, http://dblp.org}
# }
# ```

# %% [markdown]
# If you find it useful, feel welcome to leave a comment on the [blog.](https://www.wildcardconsulting.dk/useful-information/smiles-enumeration-as-data-augmentation-for-molecular-neural-networks/)
